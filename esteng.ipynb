# %% [markdown]
# # Inglise keele tõlkevastete kandidaatide saniteerimine

# %% [markdown]
# _Esta Prangel_

# %% [markdown]
# ## Sissejuhatus
#
# Andmestik on pärit sõnastikest ja paralleelkorpustest.
#
# __Sõnastikud__:
# - TEA
# - Silvet
# - Majandus
# - Indrek Hein
# - K-dictionaries
#
# __Korpused__:
# - Professionaalsed tõlkemälud
# - Avalikud paralleelkorpused
#
# Andmestikust on kaks versiooni:
# 1. `ekilex_import_data_itermax.json`
# 2. `ekilex_import_data_inter.json`
#
# Erinevus on korpuste parsimisel kasutatud joondamismetoodikas. Kõik kõrgema kaaluga kandidaadid on neis samad, aga korpustest tulevad variandid võivad erineda.
#
# Kaustas “Keelevaraga” on andmestikesse lisatud sõnastikest pärit andmed. Kui vaste kaal on suurem kui 0,9, on see pärit sõnaraamatust. Millisest sõnaraamatust, on võimalik öelda ainult siis, kui tegu on Kdictionaryga. Teiste puhul pole meil võtta definitsioone ega kasutusnäiteid ja kuna allikaviide käib nende, mitte vaste enda kohta, siis allikaviidet pole kuhugi panna. Nii et kui vaste kaal on suurem kui 0,9 ja see pole pärit Kdictionaryst, on see pärit Indrek Heina ümberpööratud sõnastikust, Tea sõnastikest, majandussõnastikust või Silveti sõnastikust.
#
# Näidissõnastik, millesugustest andmestik koosneb:
#
# ```json
# {
#     "headwordValue": "varsseller",
#     "headwordLang": "est",
#     "synCandidateDatasetCode": "ingitermax",
#     "synCandidateWords": [
#       {
#         "value": "celery",
#         "lang": "eng",
#         "weight": 0.8,
#         "posCodes": [],
#         "definitions": [],
#         "usages": []
#       },
#       {
#         "value": "ribbed",
#         "lang": "eng",
#         "weight": 0.8,
#         "posCodes": [],
#         "definitions": [],
#         "usages": []
#       },
#       {
#         "value": "piece",
#         "lang": "eng",
#         "weight": 0.8,
#         "posCodes": [],
#         "definitions": [],
#         "usages": []
#       },
#       {
#         "value": "matchstick",
#         "lang": "eng",
#         "weight": 0.8,
#         "posCodes": [],
#         "definitions": [],
#         "usages": []
#       },
#       {
#         "value": "asparagus",
#         "lang": "eng",
#         "weight": 0.8,
#         "posCodes": [],
#         "definitions": [],
#         "usages": []
#       },
#       {
#         "value": "vegetable",
#         "lang": "eng",
#         "weight": 0.8,
#         "posCodes": [],
#         "definitions": [],
#         "usages": []
#       },
#       {
#         "value": "stalk",
#         "lang": "eng",
#         "weight": 0.8,
#         "posCodes": [],
#         "definitions": [],
#         "usages": []
#       }
#     ]
#   }

# %% [markdown]
# ## Andmete saniteerimine

# %% [markdown]
# ### Andmestikud
#
# Koodi käivitamisel tuleb valida, kumma joondamismetoodikaga koostatud andmestikku töötlema hakatakse.

# %%
base_data = 'failid/andmestik/keelevaraga/ekilex_import_data_inter.json'
#base_data = 'failid/andmestik/keelevaraga/ekilex_import_data_inter_051023_100000.json'
#base_data = 'failid/andmestik/keelevaraga/ekilex_import_data_itermax.json'

# %% [markdown]
# Vajalik on loetelu ÜSi keelenditest.

# %%
ys = 'failid/andmestik/YS/_SELECT_DISTINCT_word_value_FROM_lexeme_JOIN_word_ON_lexeme_word_202310051024.csv'

# %% [markdown]
# ### Vajalike teekide import

# %%
import csv
import string
import json
import os
import random
import pandas as pd

# %% [markdown]
# ### Üleliigsete eesti keelendite eemaldamine
# #### Eemaldada keelendid, mis ei ole ÜSis
#
# Kuna lõpuks on vaja potentsiaalsed kandidaadid siduda ÜSi tähendustega, on mõtet tegelda vaid nende keelenditega, mis ÜSis olemas on. Samas tähendab see paraku, et kaduma läheb hulk keelendeid, mis on saadud korpustest.

# %%
def load_ys_file_to_set(filename):
    ys_set = set()
    with open(filename, 'r', encoding='utf-8') as csvfile:
        csvreader = csv.reader(csvfile)
        for row in csvreader:
            ys_set.add(row[0])
    return ys_set

def is_word_in_ys_file(word, ys_set):
    if word in ys_set:
        return True
    else:
        return False

ys_set = load_ys_file_to_set(ys)

with open(base_data, 'r', encoding='utf-8') as f:
    data = json.load(f)

removed_items = []
filtered_data = []

for d in data:
    headword_value = d["headwordValue"]

    if is_word_in_ys_file(headword_value, ys_set):
        filtered_data.append(d)
    else:
        removed_items.append(d)

# %% [markdown]
# #### Kokkuvõte

# %%
columns = ['Tingimus', 'Keelendeid ÜSis', 'Näited']
random_ys_values = random.sample(filtered_data, 10)
headword_ys_values = [item["headwordValue"] for item in random_ys_values]
ys_words = ', '.join(headword_ys_values)

random_not_ys_values = random.sample(removed_items, 10)
headword_not_ys_values = [item["headwordValue"] for item in random_not_ys_values]
not_ys_words = ', '.join(headword_not_ys_values)
    
ys_data = [
    ["Keelend ÜSis olemas", len(filtered_data), ys_words],
    ["Keelend puudub ÜSis", len(removed_items), not_ys_words]
]

pd.set_option('display.max_colwidth', None)

df_ys = pd.DataFrame(ys_data, columns=columns)

styled_df_ys = df_ys.style.set_properties(**{'text-align': 'left'}).set_table_styles([{
    'selector': 'th',
    'props': [('text-align', 'left')]
}]).hide()

styled_df_ys
# Out:
# <style type="text/css">
# #T_ba58b th {
#   text-align: left;
# }
# #T_ba58b_row0_col0, #T_ba58b_row0_col1, #T_ba58b_row0_col2, #T_ba58b_row1_col0, #T_ba58b_row1_col1, #T_ba58b_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_ba58b">
#   <thead>
#     <tr>
#       <th id="T_ba58b_level0_col0" class="col_heading level0 col0" >Tingimus</th>
#       <th id="T_ba58b_level0_col1" class="col_heading level0 col1" >Keelendeid ÜSis</th>
#       <th id="T_ba58b_level0_col2" class="col_heading level0 col2" >Näited</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ba58b_row0_col0" class="data row0 col0" >Keelend ÜSis olemas</td>
#       <td id="T_ba58b_row0_col1" class="data row0 col1" >109464</td>
#       <td id="T_ba58b_row0_col2" class="data row0 col2" >värviergas, väsimustugevus, õhusoojus, vankumatus, kirikuvõim, karbonaad, pinnapealsus, lipiid, valitsusside, düsenteeriaepideemia</td>
#     </tr>
#     <tr>
#       <td id="T_ba58b_row1_col0" class="data row1 col0" >Keelend puudub ÜSis</td>
#       <td id="T_ba58b_row1_col1" class="data row1 col1" >1811922</td>
#       <td id="T_ba58b_row1_col2" class="data row1 col2" >zygoptera, acocleani, defferre, tindero, kübaratäis, ricks, jäikusväärtus, asendaminesa, noraku, lisapunker</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Alles jäänud keelendid salvestatakse ajutisse JSON faili `temp_filtered_data.json`.

# %%
with open(f'output/temp_filtered_data.json', 'w', encoding='utf-8') as f:
    json.dump(filtered_data, f, ensure_ascii=False)

# %% [markdown]
# Eemaldatud keelendid salvestatakse JSON faili `words_not_in_ys.json`.

# %%
with open(f'output/words_not_in_ys.json', 'w', encoding='utf-8') as f:
    json.dump(removed_items, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ### Andmete saniteerimine
# Jätkatakse faili `temp_filtered_data.json` andmete saniteerimisega.

# %%
with open(f'output/temp_filtered_data.json', 'r', encoding='utf-8') as f:
    filtered_data = json.load(f)

# %% [markdown]
# #### Sagedusloendid
#
# Laaditakse sagedusloendid. Fail koosneb kolmest loetelust:
#
# - [Ngramid Peter Norvigi lehelt](https://norvig.com/ngrams/count_1w.txt)
# - [Sagedusloend Peter Norvigi lehelt](<https://norvig.com/ngrams/word.list>)
# - [Collins Scrabble Words (2019)](<https://drive.google.com/file/d/1oGDf1wjWp5RF_X9C7HoedhIWMh5uJs8s/view>)

# %%
with open('input/sagedusloendid.txt', 'r', encoding='utf-8') as f:
    frequency_words = set(line.strip() for line in f.readlines())

# %% [markdown]
# #### Must nimekiri
#
# Korpuste parsimisel sattus kandidaatideks eessõnu, artikleid jmt, mis polnud siinkohal olulised (nt *to*, *in*, *the*, *at*, *are*). Koos Kristina Koppeliga sai neist koostatud must nimekiri, mis nüüd laaditakse.

# %%
with open('input/blacklist.txt', 'r', encoding='utf-8') as f:
    words_to_be_ignored = set(line.strip() for line in f.readlines())

# %% [markdown]
# #### Üleliigsete inglise tõlkevastete eemaldamine ja vajadusel kohendamine
#
# Seejärel käiakse läbi massiivis olevad sõnastikud ja kontrollitakse tõlkevastete kandidaatide vastavust mitmesugustele reeglitele.
#
# Reeglitele vastavust kontrollitakse järjestikku nii, et kui keelend mingit reeglit rikub, katkestatakse tsükkel ja asutakse järgmist keelendit kontrollima. Kui keelend vastab reeglile, siis kontrollitakse vastavust järgmisele reeglile, kuni tsükkel läbi saab.
#
# Kui tõlkevaste kandidaat ei vasta reeglitele, siis lisatakse see massiivi `words_to_remove`. Kui ühe sõnastiku kõik tõlkevastete kandidaadid on läbi käidud, eemaldatakse massiivist synCandidateWords need keelendid, mis on massiivis `words_to_remove`. Nii on tsükli lõpuks massiivis `sanitized_data` sõnastikud, mis läbisid reeglite kontrolli. Paralleelselt koostatakse sõnastikud eestikeelsest keelendist ja inglise vastete kandidaatidest, mis reeglitele ei vastanud. Need sõnastikud salvestatakse massiivina `removed_items`.
#
# ##### Reeglid
#
# 1. Kui tõlkevaste kandidaat on ühesõnaline (ei sisalda tühikut ega sidekriipsu) ja selle kaal on suurem kui 0,8, siis jäetakse see alles.
# 2. Kui tõlkevaste kandidaat on ühesõnaline (ei sisalda tühikut ega sidekriipsu) ja kaal ei ole suurem kui 0,8, siis jäetakse see alles, kui sõna on sagedusloendites. Kui ei ole, eemaldatakse.
# 3. Kui tõlkevaste kandidaat on mustas nimekirjas, aga selle definitsioon on pärit KDictionaryst, siis see keelend jääb alles.
# 4. Kui tõlkevaste kandidaat on mustas nimekirjas, aga sel pole definitsiooni või definitsioon pole pärit KDictionaryst, siis see keelend eemaldatakse.
# 5. Kui väiketähtede kujule viidud tõlkevaste kandidaat algab artikliga 'the ' ja samas massiivis pole sõnastikku, mille võtme 'value' väärtus on  samasugune tõlkevaste kandidaat ilma artiklita 'the ', siis eemaldatakse artikliga variant ja jäetakse alles artiklita keelend.
# 6. Kui väiketähtede kujule viidud tõlkevaste kandidaat algab artilkiga 'the ' ja samas massiivis pole sõnastikku, mille võtme 'value' väärtus on samasugune tõlkevaste kandidaat ilma artiklita 'the ', siis eemaldatakse sõna algusest 'the '.
# 7. Kui väiketähtede kujule viidud tõlkevaste kandidaat algab artikliga 'a ' ja samas massiivis pole sõnastikku, mille võtme 'value' väärtus on  samasugune tõlkevaste kandidaat ilma artiklita 'a ', siis eemaldatakse artikliga variant ja jäetakse alles artiklita keelend.
# 8. Kui väiketähtede kujule viidud tõlkevaste kandidaat algab artilkiga 'a ' ja samas massiivis pole sõnastikku, mille võtme 'value' väärtus on samasugune tõlkevaste kandidaat ilma artiklita 'a ', siis eemaldatakse sõna algusest 'a '.
# 9. Kui väiketähtede kujule viidud tõlkevaste kandidaat algab artikliga 'an ' ja samas massiivis pole sõnastikku, mille võtme 'value' väärtus on  samasugune tõlkevaste kandidaat ilma artiklita 'an ', siis eemaldatakse artikliga variant ja jäetakse alles artiklita keelend.
# 10. Kui väiketähtede kujule viidud tõlkevaste kandidaat algab artilkiga 'an ' ja samas massiivis pole sõnastikku, mille võtme 'value' väärtus on samasugune tõlkevaste kandidaat ilma artiklita 'an ', siis eemaldatakse sõna algusest 'an '.
# 11. Kui tõlkevaste kandidaat on sõne, mis koosneb tühikuga eraldatud samasugustest sõnedest, siis jäetakse neist sõnedest alles vaid üks (nt 'hello hello' asemele jääb 'hello').
# 12. Kui tõlkevaste kandidaat algab kirjavahemärgi (!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~) ja tühikuga, siis eemaldatakse see keelend.
# 13. Kui tõlkevaste kandidaat sisaldab numbrit, siis see keelend eemaldatakse.
# 14. Kui tõlkevaste kandidaat sisaldab "'s" või " 's", siis see keelend eemaldatakse.

# %%
sanitized_data = filtered_data.copy()
removed_items = []

for d in sanitized_data:
    headword_value = d["headwordValue"]
    words_to_remove = []
    removed_items_dict = {"headwordValue": headword_value, "synCandidateWords": []}

    for item in d["synCandidateWords"]:
        if ' ' not in item['value'] and '-' not in item['value']:
            # 1. reegel:
            if item['weight'] > 0.8:
                continue
            # 2. reegel:
            if item["value"] not in frequency_words:
                words_to_remove.append(item)
                removed_items_dict["synCandidateWords"].append(item)

        if item['value'] in words_to_be_ignored:
            has_kdictionary = False
            for definition in item['definitions']:
                # 3. reegel:
                for sourceLink in definition['sourceLinks']:
                    if sourceLink['value'] == 'KDictionary':
                        has_kdictionary = True
                        break
                if has_kdictionary:
                    break
            # 4. reegel:
            if not has_kdictionary:
                words_to_remove.append(item)
                removed_items_dict["synCandidateWords"].append(item)

        if item['value'].lower().startswith('the '):
            word_without_article = item['value'][4:]
            # 5. reegel:
            if any(word_without_article == word['value'] for word in d["synCandidateWords"]):
                words_to_remove.append(item)
                removed_items_dict["synCandidateWords"].append(item)
            else:
                # 6. reegel:
                item['value'] = word_without_article

        if item['value'].lower().startswith('a '):
            word_without_article = item['value'][2:]
            # 7. reegel:
            if any(word_without_article == word['value'] for word in d["synCandidateWords"]):
                words_to_remove.append(item)
                removed_items_dict["synCandidateWords"].append(item)
            else:
                # 8. reegel:
                item['value'] = word_without_article

        if item['value'].lower().startswith('an '):
            word_without_article = item['value'][3:]
            # 9. reegel:
            if any(word_without_article == word['value'] for word in d["synCandidateWords"]):
                words_to_remove.append(item)
                removed_items_dict["synCandidateWords"].append(item)
            else:
                # 10. reegel:
                item['value'] = word_without_article

        # 11. reegel
        words = item['value'].split()
        if len(words) > 1 and all(word == words[0] for word in words):
            words_to_remove.append(item)
            removed_items_dict["synCandidateWords"].append(item)

        # 12. reegel:
        if any(item['value'].startswith(punct + " ") for punct in string.punctuation):
            words_to_remove.append(item)
            removed_items_dict["synCandidateWords"].append(item)

        # 13. reegel:
        if any(char.isdigit() for char in item['value']):
            words_to_remove.append(item)
            removed_items_dict["synCandidateWords"].append(item)

        # 14. reegel:
        if " 's" in item['value']:
            words_to_remove.append(item)
            removed_items_dict["synCandidateWords"].append(item)

    for item in words_to_remove:
        if item in d["synCandidateWords"]:
            d["synCandidateWords"].remove(item)

    if removed_items_dict["synCandidateWords"]:
        removed_items.append(removed_items_dict)

# %% [markdown]
# Eestikeelsed keelendid koos võimalike ingliskeelsete tõlkevastete kandidaatidega, mis alles jäid, salvestatakse faili.

# %%
with open('output/final_sanitized_data.json', 'w', encoding='utf-8') as f:
    json.dump(sanitized_data, f, ensure_ascii=False, indent=2)

# %% [markdown]
# Sõnastikud sobimatute ingliskeelsete vastetega salvestatakse faili.

# %%
with open('output/final_removed_words.json', 'w', encoding='utf-8') as f:
    json.dump(removed_items, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ##### Kokkuvõte

# %%
columns = ['Keelendi tüüp', 'Algandmestik', 'Ainult ÜSi keelenditega', 'Lõpptulemus', 'Vahe']

count_data = 0
for dict_item in data:
    count_data += len(dict_item['synCandidateWords'])

count_filtered_data = 0
for i in filtered_data:
    count_filtered_data += len(i['synCandidateWords'])

count_sanitized_data = 0
for i in sanitized_data:
    count_sanitized_data += len(i['synCandidateWords'])
    
data = [
    ["Eestikeelne keelend ('headwordValue')", len(data), len(filtered_data), len(sanitized_data), len(sanitized_data) - len(data)],
    ["Ingliskeelne tõlkevaste kandidaat ('value')", count_data, count_filtered_data, count_sanitized_data, count_sanitized_data - count_data]
]

df = pd.DataFrame(data, columns=columns)

styled_df = df.style.set_properties(**{'text-align': 'left'}).set_table_styles([{
    'selector': 'th',
    'props': [('text-align', 'left')]
}]).hide()

styled_df
# Out:
# <style type="text/css">
# #T_03844 th {
#   text-align: left;
# }
# #T_03844_row0_col0, #T_03844_row0_col1, #T_03844_row0_col2, #T_03844_row0_col3, #T_03844_row0_col4, #T_03844_row1_col0, #T_03844_row1_col1, #T_03844_row1_col2, #T_03844_row1_col3, #T_03844_row1_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_03844">
#   <thead>
#     <tr>
#       <th id="T_03844_level0_col0" class="col_heading level0 col0" >Keelendi tüüp</th>
#       <th id="T_03844_level0_col1" class="col_heading level0 col1" >Algandmestik</th>
#       <th id="T_03844_level0_col2" class="col_heading level0 col2" >Ainult ÜSi keelenditega</th>
#       <th id="T_03844_level0_col3" class="col_heading level0 col3" >Lõpptulemus</th>
#       <th id="T_03844_level0_col4" class="col_heading level0 col4" >Vahe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_03844_row0_col0" class="data row0 col0" >Eestikeelne keelend ('headwordValue')</td>
#       <td id="T_03844_row0_col1" class="data row0 col1" >1921386</td>
#       <td id="T_03844_row0_col2" class="data row0 col2" >109464</td>
#       <td id="T_03844_row0_col3" class="data row0 col3" >109464</td>
#       <td id="T_03844_row0_col4" class="data row0 col4" >-1811922</td>
#     </tr>
#     <tr>
#       <td id="T_03844_row1_col0" class="data row1 col0" >Ingliskeelne tõlkevaste kandidaat ('value')</td>
#       <td id="T_03844_row1_col1" class="data row1 col1" >4199247</td>
#       <td id="T_03844_row1_col2" class="data row1 col2" >994220</td>
#       <td id="T_03844_row1_col3" class="data row1 col3" >994220</td>
#       <td id="T_03844_row1_col4" class="data row1 col4" >-3205027</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Tähenduste lisamine WordNetist

# %% [markdown]
# Tähenduse lisamiseks inglise vastete kandidaatidele sai proovitud NLTK teegi kaudu saadavalolevat WordNeti.

# %% [markdown]
# Laaditakse vajalikud teegid.

# %%
import nltk
from nltk.corpus import wordnet as wn
from pprint import pprint

# %% [markdown]
# Kasutatakse saniteeritud andmestikku.

# %%
with open('output/final_sanitized_data.json', 'r', encoding='utf-8') as file:
    final_sanitized_data = json.load(file)

# %% [markdown]
# Andmestiku sõnaliikide lühendite vastavusse viimine WordNeti omadega. WordNeti klassifikatsioonis märgib _a_ 'adjectives' ja _s_ 'satellite adjectives'.

# %%
pos_mapping = {
    'n': 's',
    'v': 'v',
    'a': 'adj',
    's': 'adj',
    'r': 'adv'
}

# %% [markdown]
# Funktsioon keelendi definitsiooni saamiseks WordNetist.

# %%
def get_wordnet_definitions(word):
    synsets = wn.synsets(word)
    definitions_by_pos = {}
    for synset in synsets:
        pos = synset.pos()
        if pos not in definitions_by_pos:
            definitions_by_pos[pos] = []
        definitions_by_pos[pos].append(synset.definition())
    return definitions_by_pos

# %% [markdown]
# Funktsioon `get_wordnet_definitions` tagastab sõnastiku, milles võtmeteks on sõnaliikide lühendid ja väärtusteks definitsioonid. Näide:

# %%
pprint(get_wordnet_definitions('social'))
# Out:
# {'a': ['relating to human society and its members',
#        'living together or enjoying life in communities or organized groups',
#        'relating to or belonging to or characteristic of high society'],
#  'n': ['a party of people assembled to promote sociability and communal '
#        'activity'],
#  's': ['composed of sociable people or formed for the purpose of sociability',
#        'tending to move or live together in groups or colonies of the same '
#        'kind',
#        'marked by friendly companionship with others']}

# %% [markdown]
# Käiakse läbi saniteeritud andmestiku inglise tõlkevastete kandidaadid ja lisatakse definitsioone, kui neid on võimalik WordNetist saada.
# Definitsiooni allikaks määratakse NLTK WordNet ja allika ID-ks kohatäiteks valitud ID. Kui tõlkevaste kandidaadil on kaal olemas, kasutatakse seda, kui ei, on vaikimisi kaalu väärtuseks 1.0. Lõpptulemus on massiiv sõnastikest, kus iga sõnastik koosneb eesti keelendist ja inglise keele tõlkevastete kandidaatidest koos definitsioonidega. Kui kandidaadid on ühest sõnaliigist, on need ühes sõnastikus.

# %%
def process_data(data):
    for entry in data:
        syn_candidate_words = entry.get('synCandidateWords', [])
        new_syn_candidate_words = []

        for syn_word in syn_candidate_words:
            word_value = syn_word.get('value')
            wordnet_definitions_by_pos = get_wordnet_definitions(word_value)  # Assuming this function is defined elsewhere

            for pos, definitions in wordnet_definitions_by_pos.items():
                mapped_pos = pos_mapping.get(pos, pos)  # Assuming pos_mapping is defined elsewhere
                for defn in definitions:
                    new_word_entry = {
                        "value": word_value,
                        "lang": "eng",
                        "weight": syn_word.get('weight', 1.0),
                        "posCodes": [mapped_pos],
                        "definitions": [{"value": defn, "sourceLinks": [{"sourceId": 84967, "value": "NLTK WordNet"}]}],
                        "usages": syn_word.get('usages', [])
                    }
                    new_syn_candidate_words.append(new_word_entry)

            for existing_defn in syn_word.get('definitions', []):
                new_word_entry = {
                    "value": word_value,
                    "lang": "eng",
                    "weight": syn_word.get('weight', 1.0),
                    "posCodes": syn_word.get('posCodes', []),
                    "definitions": [existing_defn],
                    "usages": syn_word.get('usages', [])
                }
                new_syn_candidate_words.append(new_word_entry)

        merged_by_posCodes = {}

        for d in new_syn_candidate_words:
            posCodes_key = tuple(d['posCodes'])
            if posCodes_key in merged_by_posCodes:
                merged_by_posCodes[posCodes_key]['definitions'] += d['definitions']
            else:
                merged_by_posCodes[posCodes_key] = d

        merged_dicts = list(merged_by_posCodes.values())

        entry['synCandidateWords'] = merged_dicts

    return data

processed_data = process_data(final_sanitized_data)

# %% [markdown]
# Näide esimesest eesti keelendist, mille inglise keele tõlkevaste kandidaadile on lisatud WordNetist definitsioon.

# %%
for item in processed_data:
    for syn_word in item['synCandidateWords']:
        found = False
        for definition in syn_word['definitions']:
            for source_link in definition['sourceLinks']:
                if source_link['value'] == 'NLTK WordNet':
                    print(json.dumps(item, indent=2, ensure_ascii=False))
                    found = True
                    break
            if found:
                break
        if found:
            break
    if found:
        break
# Out:
# {
#   "headwordValue": "sotsiaalhoolekanne",
#   "headwordLang": "est",
#   "synCandidateDatasetCode": "ingitermax",
#   "synCandidateWords": [
#     {
#       "value": "social work",
#       "lang": "eng",
#       "weight": 0.9,
#       "posCodes": [
#         "s"
#       ],
#       "definitions": [
#         {
#           "value": "work which deals with the care of people in a community, especially of the poor, under-privileged etc.",
#           "sourceLinks": [
#             {
#               "sourceId": 20647,
#               "value": "KDictionary"
#             }
#           ]
#         },
#         {
#           "value": "a party of people assembled to promote sociability and communal activity",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "governmental provision of economic assistance to persons in need",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "something that aids or promotes well-being",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a contented state of being happy and healthy and prosperous",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "activity directed toward making or doing something",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a product produced or accomplished through the effort or activity or agency of a person or thing",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the occupation for which you are paid",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "applying the mind to learning and understanding a subject (especially by reading)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "(physics) a manifestation of energy; the transfer of energy from one physical system to another expressed as the product of a force and the distance through which it moves a body in the direction of that force",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a place where work is done",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the total output of a writer or artist (or a substantial part of it)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a stipulated condition",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the activity of supplying or providing something",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the cognitive process of thinking about what you will do in the event of something happening",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a store or supply of something (especially of food or clothing or arms)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the work of providing treatment for or attending to someone or something",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "judiciousness in avoiding harm or danger",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "an anxious feeling",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a cause for feeling concern",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "attention and management implying responsibility for safety",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "activity involved in maintaining something in good working order",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "work done by one person or group that benefits another",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "an act of help or assistance",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the act of public worship following prescribed rules",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a company or agency that performs a public service; subject to government regulation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "employment in or work for another",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a force that is a branch of the armed forces",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "Canadian writer (born in England) who wrote about life in the Yukon Territory (1874-1958)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a means of serving",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "tableware consisting of a complete set of articles (silver or dishware) for use at table",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the act of mating by male animals",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "(law) the acts performed by an English feudal tenant for the benefit of his lord which formed the consideration for the property granted to him",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "(sports) a stroke that puts the ball in play",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the act of delivering a writ or summons upon someone",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "periodic maintenance on a car or machine",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the performance of duties by a waiter or servant",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "minimal (or marginal) resources for subsisting",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a means of surviving",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the state of existing in reality; having substance",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the preservation of mental and physical health by preventing or treating illness through services offered by the health profession",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a healthy state of wellbeing free from disease",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the general condition of body and mind",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the state of being free from danger or injury",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "defense against financial failure; financial independence",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "freedom from anxiety or fear",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a formal declaration that documents a fact of relevance to finance and investment; the holder has a right to receive interest or dividends",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "property that your creditor can claim in case you default on your obligation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a department responsible for the security of the institution's property and workers",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a guarantee that an obligation will be met",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "an electrical device that sets off an alarm when someone tries to break in",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "measures taken as a precaution against theft or espionage or sabotage etc.",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "any specific behavior",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the state of being active",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "an organic process that takes place in the body",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "(chemistry) the capacity of a substance to take part in a chemical reaction",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a process existing in or produced by nature (rather than by the intent of human beings)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the trait of being active; moving or acting rapidly and energetically",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "people in general considered as a whole",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a body of people sharing some common interest",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the restoration of someone to a useful place in society",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the conversion of wasteland into land suitable for use of habitation or cultivation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "vindication of a person's character and the re-establishment of that person's reputation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the treatment of physical disabilities by massage and electrotherapy and exercises",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "an activity that diverts or amuses or stimulates",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "activity that refreshes and recreates; activity that renews your health and spirits by enjoyment and relaxation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "United States songwriter whose songs embody the sentiment of the South before the American Civil War (1826-1864)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a written assurance that some product or service will be provided or will meet certain specifications",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "an unconditional commitment that something will happen or that something is true",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a collateral agreement to answer for the debt of another in case that person defaults",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a loving feeling",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a person who works at a specific occupation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a member of the working class (not necessarily employed)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "sterile member of a colony of social insects that forages for food and cares for the larvae",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a person who acts and gets things done",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the quality of being just or fair",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "judgment involved in the determination of rights and the assignment of rewards and punishments",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a public official authorized to decide questions brought before a court of justice",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the United States federal department responsible for enforcing federal laws (including the enforcement of all civil rights legislation); created in 1870",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the system of production and distribution and consumption",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the efficient use of resources",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "frugality in the expenditure of money or resources",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "an act of economizing; reduction in cost",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "act of improving by expanding or enlarging or refining",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a process in which something passes by degrees to a different stage (especially a more advanced or mature stage)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "(biology) the process of an individual organism growing organically; a purely biological unfolding of events involved in an organism changing gradually from a simple to a more complex level",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a recent event that has some relevance for the present situation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "the act of making some area of land or water more profitable or productive or useful",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a district that has been developed to serve some purpose",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a state in which things are improving; the result of developing (as in the early part of a game of chess)",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "processing a photosensitive material in order to make an image visible",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "(music) the section of a composition or movement (especially in sonata form) where the major musical themes are developed and elaborated",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "governmental provision of economic assistance to persons in need",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "something that aids or promotes well-being",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "a contented state of being happy and healthy and prosperous",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         }
#       ],
#       "usages": []
#     },
#     {
#       "value": "social",
#       "lang": "eng",
#       "weight": 0.8,
#       "posCodes": [
#         "adj"
#       ],
#       "definitions": [
#         {
#           "value": "relating to human society and its members",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "living together or enjoying life in communities or organized groups",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "relating to or belonging to or characteristic of high society",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "composed of sociable people or formed for the purpose of sociability",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "tending to move or live together in groups or colonies of the same kind",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "marked by friendly companionship with others",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "of a nerve fiber or impulse originating outside and passing toward the central nervous system",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "involving or derived from the senses",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "relating to or concerned in sensation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "not private; open to or concerning the people as a whole",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "affecting the people or community as a whole",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "providing or receiving nurture or parental care though not related by blood or legal ties",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "feeling and exhibiting concern and empathy for others",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "used or designed for residence or limited to residences",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "of or relating to or connected with residence",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         }
#       ],
#       "usages": []
#     },
#     {
#       "value": "work",
#       "lang": "eng",
#       "weight": 0.8,
#       "posCodes": [
#         "v"
#       ],
#       "definitions": [
#         {
#           "value": "exert oneself by doing mental or physical work for a purpose or out of necessity",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "be employed",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "have an effect or outcome; often the one desired or expected",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "perform as expected when applied",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "shape, form, or improve a material",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "give a workout to",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "proceed along a path",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "operate in a certain place, area, or specialty",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "proceed towards a goal or along a path or through an activity",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "move in an agitated manner",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "cause to happen or to occur as a consequence",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "cause to work",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "prepare for crops",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "behave in a certain way when handled",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "have and exert influence or effect",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "operate in or through",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "cause to operate or function",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "provoke or excite",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "gratify and charm, usually in order to influence",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "make something, usually for a specific function",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "move into or onto",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "make uniform",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "use or manipulate to one's advantage",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "find the solution to (a problem or question) or understand the meaning of",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "cause to undergo fermentation",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "go sour or spoil",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "arrive at a certain condition through repeated motion",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "supply with provisions",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "feel concern or interest",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "provide care for",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "prefer or wish to do something",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "be in charge of, act on, or dispose of",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "be concerned with",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "be used by; as of a utility",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "make fit for use",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "mate with",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "promote the growth of",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "bring up under fosterage; of children",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "help develop, help grow",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "give surety or assume responsibility",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "make certain of",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "promise to do or accomplish",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "stand behind and guarantee the quality, accuracy, or condition of",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "feel concern or interest",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "provide care for",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "prefer or wish to do something",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "be in charge of, act on, or dispose of",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         },
#         {
#           "value": "be concerned with",
#           "sourceLinks": [
#             {
#               "sourceId": 84967,
#               "value": "NLTK WordNet"
#             }
#           ]
#         }
#       ],
#       "usages": []
#     }
#   ]
# }

# %% [markdown]
# Tulemus salvestatakse faili.

# %%
with open('output/data_with_wordnet_definitions.json', 'w', encoding='utf-8') as file:
    json.dump(processed_data, file, indent=4, ensure_ascii=False)
